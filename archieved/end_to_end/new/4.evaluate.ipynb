# %% [markdown]
# ### feature extraction

# %%
from feature_extractor import *
from data_preprocess import *
from common.utils import ImageSlice, ImageSliceInMemory
import os
import gc
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class_feature_extrctor = FeatureExtrctor(gpu_num = 4, gpus = "0,1,2,3")
class_feature_extrctor.build_model()
# Out:
# input_2
# lambda_2
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_conv4
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_conv4
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_conv4
# block5_pool
# flatten
# fc1
# drop_fc1
# fc2
# drop_fc2
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# lambda_2 (Lambda)            (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# drop_fc1 (Dropout)           (None, 4096)              0
# _________________________________________________________________
# fc2 (Dense)                  (None, 512)               2097664
# _________________________________________________________________
# drop_fc2 (Dropout)           (None, 512)               0
# =================================================================
# Total params: 124,886,592
# Trainable params: 124,886,592
# Non-trainable params: 0
# _________________________________________________________________
#     build completed!

# %%
features = []
err = 0

# predict img pathes
# data_dir = "/home/sakulaki/TCTDATA/gz_new_unlabeled/2018-06-11-normal/"
data_dir = "/home/sakulaki/TCTDATA_test/20180813/"
images_origin = os.listdir(data_dir)

for i, image in enumerate(images_origin):
    err = class_feature_extrctor.read_big_pic(data_dir + image)
    if (0 == err):
        feature = class_feature_extrctor.feature_extrctor()
        features.append(feature)
    else:
        # error, do nothing
        pass

features = np.array(features)

del class_feature_extrctor
gc.collect()
# Out:
# /home/sakulaki/TCTDATA_test/20180813/2018-08-13-15_02_29.kfb
# Image Process /home/sakulaki/TCTDATA_test/20180813/2018-08-13-15_02_29.kfb ...
# Adding Job to Pool...
# 28672 28672
# Done, cost: 0:00:00.888169, Total Job Count: 128, Worker Count: 26
# One Job Done, Got 128 patches, last Job Count: 127
# One Job Done, Got 128 patches, last Job Count: 126
# One Job Done, Got 128 patches, last Job Count: 125
# One Job Done, Got 128 patches, last Job Count: 124
# One Job Done, Got 128 patches, last Job Count: 123
# One Job Done, Got 128 patches, last Job Count: 122
# One Job Done, Got 128 patches, last Job Count: 121
# One Job Done, Got 128 patches, last Job Count: 120
# One Job Done, Got 128 patches, last Job Count: 119
# One Job Done, Got 128 patches, last Job Count: 118
# One Job Done, Got 128 patches, last Job Count: 117
# One Job Done, Got 128 patches, last Job Count: 116
# One Job Done, Got 128 patches, last Job Count: 115
# One Job Done, Got 128 patches, last Job Count: 114
# One Job Done, Got 128 patches, last Job Count: 113
# One Job Done, Got 128 patches, last Job Count: 112
# One Job Done, Got 128 patches, last Job Count: 111
# One Job Done, Got 128 patches, last Job Count: 110
# One Job Done, Got 128 patches, last Job Count: 109
# One Job Done, Got 128 patches, last Job Count: 108
# One Job Done, Got 128 patches, last Job Count: 107
# One Job Done, Got 128 patches, last Job Count: 106
# One Job Done, Got 128 patches, last Job Count: 105
# One Job Done, Got 128 patches, last Job Count: 104
# One Job Done, Got 128 patches, last Job Count: 103
# One Job Done, Got 128 patches, last Job Count: 102
# One Job Done, Got 128 patches, last Job Count: 101
# One Job Done, Got 128 patches, last Job Count: 100
# One Job Done, Got 128 patches, last Job Count: 99
# One Job Done, Got 128 patches, last Job Count: 98
# One Job Done, Got 128 patches, last Job Count: 97
# One Job Done, Got 128 patches, last Job Count: 96
# One Job Done, Got 128 patches, last Job Count: 95
# One Job Done, Got 128 patches, last Job Count: 94
# One Job Done, Got 128 patches, last Job Count: 93
# One Job Done, Got 128 patches, last Job Count: 92
# One Job Done, Got 128 patches, last Job Count: 91
# One Job Done, Got 128 patches, last Job Count: 90
# One Job Done, Got 128 patches, last Job Count: 89
# One Job Done, Got 128 patches, last Job Count: 88
# One Job Done, Got 128 patches, last Job Count: 87
# One Job Done, Got 128 patches, last Job Count: 86
# One Job Done, Got 128 patches, last Job Count: 85
# One Job Done, Got 128 patches, last Job Count: 84
# One Job Done, Got 128 patches, last Job Count: 83
# One Job Done, Got 128 patches, last Job Count: 82
# One Job Done, Got 128 patches, last Job Count: 81
# One Job Done, Got 128 patches, last Job Count: 80
# One Job Done, Got 128 patches, last Job Count: 79
# One Job Done, Got 128 patches, last Job Count: 78
# One Job Done, Got 128 patches, last Job Count: 77
# One Job Done, Got 128 patches, last Job Count: 76
# One Job Done, Got 128 patches, last Job Count: 75
# One Job Done, Got 128 patches, last Job Count: 74
# One Job Done, Got 128 patches, last Job Count: 73
# One Job Done, Got 128 patches, last Job Count: 72
# One Job Done, Got 128 patches, last Job Count: 71
# One Job Done, Got 128 patches, last Job Count: 70
# One Job Done, Got 128 patches, last Job Count: 69
# One Job Done, Got 128 patches, last Job Count: 68
# One Job Done, Got 128 patches, last Job Count: 67
# One Job Done, Got 128 patches, last Job Count: 66
# One Job Done, Got 128 patches, last Job Count: 65
# One Job Done, Got 128 patches, last Job Count: 64
# One Job Done, Got 128 patches, last Job Count: 63
# One Job Done, Got 128 patches, last Job Count: 62
# One Job Done, Got 128 patches, last Job Count: 61
# One Job Done, Got 128 patches, last Job Count: 60
# One Job Done, Got 128 patches, last Job Count: 59
# One Job Done, Got 128 patches, last Job Count: 58
# One Job Done, Got 128 patches, last Job Count: 57
# One Job Done, Got 128 patches, last Job Count: 56
# One Job Done, Got 128 patches, last Job Count: 55
# One Job Done, Got 128 patches, last Job Count: 54
# One Job Done, Got 128 patches, last Job Count: 53
# One Job Done, Got 128 patches, last Job Count: 52
# One Job Done, Got 128 patches, last Job Count: 51
# One Job Done, Got 128 patches, last Job Count: 50
# One Job Done, Got 128 patches, last Job Count: 49
# One Job Done, Got 128 patches, last Job Count: 48
# One Job Done, Got 128 patches, last Job Count: 47
# One Job Done, Got 128 patches, last Job Count: 46
# One Job Done, Got 128 patches, last Job Count: 45
# One Job Done, Got 128 patches, last Job Count: 44
# One Job Done, Got 128 patches, last Job Count: 43
# One Job Done, Got 128 patches, last Job Count: 42
# One Job Done, Got 128 patches, last Job Count: 41
# One Job Done, Got 128 patches, last Job Count: 40
# One Job Done, Got 128 patches, last Job Count: 39
# One Job Done, Got 128 patches, last Job Count: 38
# One Job Done, Got 128 patches, last Job Count: 37
# One Job Done, Got 128 patches, last Job Count: 36
# One Job Done, Got 128 patches, last Job Count: 35
# One Job Done, Got 128 patches, last Job Count: 34
# One Job Done, Got 128 patches, last Job Count: 33
# One Job Done, Got 128 patches, last Job Count: 32
# One Job Done, Got 128 patches, last Job Count: 31
# One Job Done, Got 128 patches, last Job Count: 30
# One Job Done, Got 128 patches, last Job Count: 29
# One Job Done, Got 128 patches, last Job Count: 28
# One Job Done, Got 128 patches, last Job Count: 27
# One Job Done, Got 128 patches, last Job Count: 26
# One Job Done, Got 128 patches, last Job Count: 25
# One Job Done, Got 128 patches, last Job Count: 24
# One Job Done, Got 128 patches, last Job Count: 23
# One Job Done, Got 128 patches, last Job Count: 22
# One Job Done, Got 128 patches, last Job Count: 21
# One Job Done, Got 128 patches, last Job Count: 20
# One Job Done, Got 128 patches, last Job Count: 19
# One Job Done, Got 128 patches, last Job Count: 18
# One Job Done, Got 128 patches, last Job Count: 17
# One Job Done, Got 128 patches, last Job Count: 16
# One Job Done, Got 128 patches, last Job Count: 15
# One Job Done, Got 128 patches, last Job Count: 14
# One Job Done, Got 128 patches, last Job Count: 13
# One Job Done, Got 128 patches, last Job Count: 12
# One Job Done, Got 128 patches, last Job Count: 11
# One Job Done, Got 128 patches, last Job Count: 10
# One Job Done, Got 128 patches, last Job Count: 9
# One Job Done, Got 128 patches, last Job Count: 8
# One Job Done, Got 128 patches, last Job Count: 7
# One Job Done, Got 128 patches, last Job Count: 6
# One Job Done, Got 128 patches, last Job Count: 5
# One Job Done, Got 128 patches, last Job Count: 4
# One Job Done, Got 128 patches, last Job Count: 3
# One Job Done, Got 128 patches, last Job Count: 2
# One Job Done, Got 128 patches, last Job Count: 1
# One Job Done, Got 128 patches, last Job Count: 0
# File - 2018-08-13-15_02_29, Size: (54008, 52975), Got Patch Num 16384, Total cost time: 0:00:07.781824
#  2432/16384 [===>..........................] - ETA: 56s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-32dd5320df27> in <module>()
#      10     err = class_feature_extrctor.read_big_pic(data_dir + image)
#      11     if (0 == err):
# ---> 12         feature = class_feature_extrctor.feature_extrctor()
#      13         features.append(feature)
#      14     else:
#
# /home/sakulaki/code/lbp_new_arch/feature_extractor.py in feature_extrctor(self)
#      95
#      96     def feature_extrctor(self):
# ---> 97         result_all = self.model.predict(self.pics, batch_size=128, verbose=1)
#      98         result_all = np.array(result_all)
#      99         result_all_format = result_all.reshape(128,128, 512)
#
# ~/anaconda3/envs/algo-work/lib/python3.5/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1170                                             batch_size=batch_size,
#    1171                                             verbose=verbose,
# -> 1172                                             steps=steps)
#    1173
#    1174     def train_on_batch(self, x, y,
#
# ~/anaconda3/envs/algo-work/lib/python3.5/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     295                 ins_batch[i] = ins_batch[i].toarray()
#     296
# --> 297             batch_outs = f(ins_batch)
#     298             if not isinstance(batch_outs, list):
#     299                 batch_outs = [batch_outs]
#
# ~/anaconda3/envs/algo-work/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2659                 return self._legacy_call(inputs)
#    2660
# -> 2661             return self._call(inputs)
#    2662         else:
#    2663             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/algo-work/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2629                                 symbol_vals,
#    2630                                 session)
# -> 2631         fetched = self._callable_fn(*array_vals)
#    2632         return fetched[:len(self.outputs)]
#    2633
#
# ~/anaconda3/envs/algo-work/lib/python3.5/site-packages/tensorflow/python/client/session.py in __call__(self, *args)
#    1449         if self._session._created_with_new_api:
#    1450           return tf_session.TF_SessionRunCallable(
# -> 1451               self._session._session, self._handle, args, status, None)
#    1452         else:
#    1453           return tf_session.TF_DeprecatedSessionRunCallable(
#
# KeyboardInterrupt:

# %%
import h5py
h5f = h5py.File('./features_test.h5', 'w')
h5f.create_dataset('features', data=features)
h5f.close()

# %% [markdown]
# ### diagnosis

# %%
from keras.models import *
from keras.layers import *
from keras.applications import *
from keras.preprocessing.image import *
from keras import optimizers
from keras.applications.vgg19 import preprocess_input
from keras.utils.training_utils import multi_gpu_model
from keras.utils import to_categorical
import tensorflow as tf
import cv2
import os
import random
import h5py
import numpy as np

# %%
h5f = h5py.File('./features_test.h5','r')
features = h5f['features'][:]
h5f.close()
print("du", features.shape)
# Out:
# du (39, 128, 128, 512)

# %%
with tf.device('/cpu:0'):
    input_tensor = Input((128, 128, 512))
    
    conv1_1 = Conv2D(filters = 1024, kernel_size = (3, 3), strides = (1, 1),
                   activation='relu', padding='same', name='conv1_1')(input_tensor)
    conv1_2 = Conv2D(filters = 1024, kernel_size = (1, 1), strides = (1, 1),
                   activation='relu', padding='same', name='conv1_2')(conv1_1)
    mp1 = MaxPooling2D(pool_size=(2, 2), strides=2, padding='same')(conv1_2)
    
    conv2_1 = Conv2D(filters = 2048, kernel_size = (3, 3), strides = (1, 1),
                   activation='relu', padding='same', name='conv2_1')(mp1)
    conv2_2 = Conv2D(filters = 2048, kernel_size = (1, 1), strides = (1, 1),
                   activation='relu', padding='same', name='conv2_2')(conv2_1)
    mp2 = MaxPooling2D(pool_size=(2, 2), strides=2, padding='same')(conv2_2)
    
    conv3_1 = Conv2D(filters = 4096, kernel_size = (3, 3), strides = (1, 1),
                   activation='relu', padding='same', name='conv3_1')(mp2)
    conv3_2 = Conv2D(filters = 2048, kernel_size = (1, 1), strides = (1, 1),
                   activation='relu', padding='same', name='conv3_2')(conv3_1)
    mp3 = MaxPooling2D(pool_size=(2, 2), strides=2, padding='same')(conv3_2)
    
    conv4_1 = Conv2D(filters = 4096, kernel_size = (3, 3), strides = (1, 1),
                   activation='relu', padding='same', name='conv4_1')(mp3)
    conv4_2 = Conv2D(filters = 2048, kernel_size = (1, 1), strides = (1, 1),
                   activation='relu', padding='same', name='conv4_2')(conv4_1)
    mp4 = MaxPooling2D(pool_size=(2, 2), strides=2, padding='same')(conv4_2)
    
    conv5_1 = Conv2D(filters = 4096, kernel_size = (3, 3), strides = (1, 1),
                   activation='relu', padding='same', name='conv5_1')(mp4)
    conv5_2 = Conv2D(filters = 2048, kernel_size = (1, 1), strides = (1, 1),
                   activation='relu', padding='same', name='conv5_2')(conv5_1)

    gmp = GlobalMaxPooling2D()(conv5_2)
    drop = Dropout(0.5, name='drop_fc1')(gmp)
    predictions = Dense(2, activation='softmax')(drop)

    model = Model(inputs=input_tensor, outputs=predictions)
    model.load_weights('diagnosis.h5')
    model.summary()

parallel_model = multi_gpu_model(model, gpus=4)
parallel_model.summary()

result = parallel_model.predict(features, batch_size=4, verbose=1)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_8 (InputLayer)         (None, 128, 128, 512)     0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 128, 128, 1024)    4719616
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 128, 128, 1024)    1049600
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 64, 64, 1024)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 64, 64, 2048)      18876416
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 64, 64, 2048)      4196352
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 32, 32, 2048)      0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 32, 32, 4096)      75501568
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 32, 32, 2048)      8390656
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 16, 16, 2048)      0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 16, 16, 4096)      75501568
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 16, 16, 2048)      8390656
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 8, 8, 2048)        0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 8, 8, 4096)        75501568
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 8, 8, 2048)        8390656
# _________________________________________________________________
# global_max_pooling2d_6 (Glob (None, 2048)              0
# _________________________________________________________________
# drop_fc1 (Dropout)           (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 4098
# =================================================================
# Total params: 280,522,754
# Trainable params: 280,522,754
# Non-trainable params: 0
# _________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            (None, 128, 128, 512 0
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 128, 128, 512 0           input_8[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 128, 128, 512 0           input_8[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 128, 128, 512 0           input_8[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 128, 128, 512 0           input_8[0][0]
# __________________________________________________________________________________________________
# model_10 (Model)                (None, 2)            280522754   lambda_7[0][0]
#                                                                  lambda_8[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_10[0][0]
# __________________________________________________________________________________________________
# dense_6 (Concatenate)           (None, 2)            0           model_10[1][0]
#                                                                  model_10[2][0]
#                                                                  model_10[3][0]
#                                                                  model_10[4][0]
# ==================================================================================================
# Total params: 280,522,754
# Trainable params: 280,522,754
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 39/39 [==============================] - 8s 208ms/step

# %% [markdown]
# ### evaluate

# %%
class_name = ['Normal', 'Abnormal']
for i, r in enumerate(result):
    print("du", images_origin[i], ":", class_name[np.argmax(r)])
# Out:
# du 2018-08-13-15_02_29.kfb : Normal
# du 2018-08-13-14_55_37.kfb : Abnormal
# du 2018-08-13-15_14_51.kfb : Abnormal
# du 2018-08-13-15_18_04.kfb : Abnormal
# du 2018-08-13-14_47_18.kfb : Abnormal
# du 2018-08-13-14_24_38.kfb : Normal
# du 2018-08-13-14_41_38.kfb : Normal
# du 2018-08-13-14_19_27.kfb : Normal
# du 2018-08-13-15_09_48.kfb : Abnormal
# du 2018-08-13-14_29_33.kfb : Abnormal
# du 2018-08-13-14_22_54.kfb : Abnormal
# du 2018-08-13-14_31_19.kfb : Abnormal
# du 2018-08-13-15_16_28.kfb : Abnormal
# du 2018-08-13-14_33_05.kfb : Normal
# du 2018-08-13-15_24_52.kfb : Abnormal
# du 2018-08-13-15_04_07.kfb : Normal
# du 2018-08-13-15_21_29.kfb : Abnormal
# du 2018-08-13-14_59_06.kfb : Abnormal
# du 2018-08-13-14_52_19.kfb : Normal
# du 2018-08-13-14_54_02.kfb : Abnormal
# du 2018-08-13-14_48_56.kfb : Normal
# du 2018-08-13-15_19_47.kfb : Normal
# du 2018-08-13-15_11_25.kfb : Normal
# du 2018-08-13-14_45_38.kfb : Abnormal
# du 2018-08-13-14_21_10.kfb : Abnormal
# du 2018-08-13-14_50_37.kfb : Abnormal
# du 2018-08-13-14_43_21.kfb : Normal
# du 2018-08-13-14_36_31.kfb : Abnormal
# du 2018-08-13-15_00_50.kfb : Normal
# du 2018-08-13-15_23_11.kfb : Normal
# du 2018-08-13-15_08_07.kfb : Abnormal
# du 2018-08-13-14_39_58.kfb : Abnormal
# du 2018-08-13-14_38_13.kfb : Normal
# du 2018-08-13-15_05_43.kfb : Normal
# du 2018-08-13-14_15_41.kfb : Normal
# du 2018-08-13-14_34_46.kfb : Abnormal
# du 2018-08-13-15_26_39.kfb : Normal
# du 2018-08-13-15_13_09.kfb : Abnormal
# du 2018-08-13-14_57_19.kfb : Abnormal
