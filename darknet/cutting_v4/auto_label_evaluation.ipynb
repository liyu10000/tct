# %%
import os
import pickle
from auto_label_evaluation import *

# %%
patch_path = "/home/ssd_array0/Data/batch6.5_1216/original"
txt_names = scan_files(patch_path, postfix=".txt")
print("# txts", len(txt_names))

patch_info_map = map_patch_info(txt_names)
print(len(patch_info_map))
# Out:
# # txts 1130184
# One Job Done, Remaining Job Count: 113
# One Job Done, Remaining Job Count: 112
# One Job Done, Remaining Job Count: 111
# One Job Done, Remaining Job Count: 110
# One Job Done, Remaining Job Count: 109
# One Job Done, Remaining Job Count: 108
# One Job Done, Remaining Job Count: 107
# One Job Done, Remaining Job Count: 106
# One Job Done, Remaining Job Count: 105
# One Job Done, Remaining Job Count: 104
# One Job Done, Remaining Job Count: 103
# One Job Done, Remaining Job Count: 102
# One Job Done, Remaining Job Count: 101
# One Job Done, Remaining Job Count: 100
# One Job Done, Remaining Job Count: 99
# One Job Done, Remaining Job Count: 98
# One Job Done, Remaining Job Count: 97
# One Job Done, Remaining Job Count: 96
# One Job Done, Remaining Job Count: 95
# One Job Done, Remaining Job Count: 94
# One Job Done, Remaining Job Count: 93
# One Job Done, Remaining Job Count: 92
# One Job Done, Remaining Job Count: 91
# One Job Done, Remaining Job Count: 90
# ...

# %%
cell_path = "/home/ssd_array0/Data/batch6.4_1216/autolabel"

img_names = scan_files(cell_path, postfix=".bmp")
print("# cells", len(img_names))

cell_info_map = map_cell_info(img_names)
print(len(cell_info_map))
# Out:
# # cells 3327962
# processed  0
# processed  10000
# processed  20000
# processed  30000
# processed  40000
# processed  50000
# processed  60000
# processed  70000
# processed  80000
# processed  90000
# processed  100000
# processed  110000
# processed  120000
# processed  130000
# processed  140000
# processed  150000
# processed  160000
# processed  170000
# processed  180000
# processed  190000
# processed  200000
# processed  210000
# processed  220000
# processed  230000
# processed  240000
# processed  250000
# processed  260000
# processed  270000
# processed  280000
# processed  290000
# processed  300000
# processed  310000
# processed  320000
# processed  330000
# processed  340000
# processed  350000
# processed  360000
# processed  370000
# processed  380000
# processed  390000
# processed  400000
# processed  410000
# processed  420000
# processed  430000
# processed  440000
# processed  450000
# processed  460000
# processed  470000
# processed  480000
# ...

# %%
summary = evaluate(patch_info_map, cell_info_map)

# %%
for key,value in summary.items():
    print(key, value)
# Out:
# EC {'recall-thres': 9587, 'patches': 11586, 'marked': 13509, 'recall': 10085, 'predicted-thres': 10007, 'predicted': 10886}
# SCC {'recall-thres': 12608, 'patches': 69365, 'marked': 95506, 'recall': 14804, 'predicted-thres': 13000, 'predicted': 15882}
# PH {'recall-thres': 41265, 'patches': 50516, 'marked': 56987, 'recall': 42781, 'predicted-thres': 58056, 'predicted': 60382}
# AGC {'recall-thres': 15227, 'patches': 35507, 'marked': 52028, 'recall': 16250, 'predicted-thres': 18357, 'predicted': 20431}
# SC {'recall-thres': 41121, 'patches': 65139, 'marked': 67062, 'recall': 45559, 'predicted-thres': 51054, 'predicted': 66702}
# VIRUS {'recall-thres': 52618, 'patches': 42560, 'marked': 92095, 'recall': 54160, 'predicted-thres': 49314, 'predicted': 51651}
# TRI {'recall-thres': 226826, 'patches': 257238, 'marked': 698555, 'recall': 227452, 'predicted-thres': 369081, 'predicted': 370425}
# ...

# %%
with open("original0429.pkl", 'wb') as f:
    pickle.dump(patch_info_map, f)
    pickle.dump(cell_info_map, f)

# %%
# with open("original.pkl", 'rb') as f:
#     patch_info_map = pickle.load(f)
#     cell_info_map = pickle.load(f)

# %%
print(len(patch_info_map))
print(len(cell_info_map))
# Out:
# 1130184
# 1268235

# %%
all_labels = collect_all_labels(patch_info_map, cell_info_map)

# %%
all_labels_summary = {key:0 for key in classes}

for name,label_boxes in all_labels.items():
    for label_box in label_boxes:
        all_labels_summary[label_box[0]] += 1
        
print(all_labels_summary)
# Out:
# {'EC': 14328, 'SCC': 96493, 'PH': 61448, 'AGC': 54916, 'SC': 69222, 'VIRUS': 99374, 'TRI': 838405, 'FUNGI': 135436, 'CC': 176330, 'ACTINO': 113070, 'HSIL': 637515, 'LSIL': 83256, 'ASCUS': 52048}

# %%
patch_labels_summary = {key:0 for key in classes}

for name,label_boxes in patch_info_map.items():
    for label_box in label_boxes:
        patch_labels_summary[label_box[0]] += 1
        
print(patch_labels_summary)
# Out:
# {'EC': 13509, 'SCC': 95506, 'PH': 56987, 'AGC': 52028, 'SC': 67062, 'VIRUS': 92095, 'TRI': 698555, 'FUNGI': 103315, 'CC': 132169, 'ACTINO': 105510, 'HSIL': 595052, 'LSIL': 79786, 'ASCUS': 48926}

# %% [markdown]
# ### write all labels

# %%
txt_path = "/home/ssd_array0/Data/batch6.5_1216/original"
write_all_labels(all_labels, txt_path)
# Out:
# # txts to write 1130184
# One Job Done, Remaining Job Count: 113
# One Job Done, Remaining Job Count: 112
# One Job Done, Remaining Job Count: 111
# One Job Done, Remaining Job Count: 110
# One Job Done, Remaining Job Count: 109
# One Job Done, Remaining Job Count: 108
# One Job Done, Remaining Job Count: 107
# One Job Done, Remaining Job Count: 106
# One Job Done, Remaining Job Count: 105
# One Job Done, Remaining Job Count: 104
# One Job Done, Remaining Job Count: 103
# One Job Done, Remaining Job Count: 102
# One Job Done, Remaining Job Count: 101
# One Job Done, Remaining Job Count: 100
# One Job Done, Remaining Job Count: 99
# One Job Done, Remaining Job Count: 98
# One Job Done, Remaining Job Count: 97
# One Job Done, Remaining Job Count: 96
# One Job Done, Remaining Job Count: 95
# One Job Done, Remaining Job Count: 94
# One Job Done, Remaining Job Count: 93
# One Job Done, Remaining Job Count: 92
# One Job Done, Remaining Job Count: 91
# One Job Done, Remaining Job Count: 90
# ...
